# %%
#1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

''' 
step1:  T(1)=3T(n-1)+12n
        T(1)=3T(0)+12
        T(1)=3(5)+12
        T(1)=15+12
        T(1)=27

step2:  T(2)=3T(n-1)+12n
        T(2)=3T(1)+12*2
        T(2)=3(27)+24
        T(2)=105

So the the T(2) is 105
'''
# Out:
# ' \nstep1:  T(1)=3T(n-1)+12n\n        T(1)=3T(0)+12\n        T(1)=3(5)+12\n        T(1)=15+12\n        T(1)=27\n\nstep2:  T(2)=3T(n-1)+12n\n        T(2)=3T(1)+12*2\n        T(2)=3(27)+24\n        T(2)=105\n\nSo the the T(2) is 105\n'

# %%
#2. Given a recurrence relation, solve it using the substitution method:
#a. T(n) = T(n-1) + c

'''
T(0)=d  means some constant term

T(n)=T(n-1)+c

#step1:

T(n)=T(n-2)+(n-1)+2c

#step2:
T(n)=T(n-3)+(n-2)+(n-1)+3c

Now what I observe these n-3,n-2,n-1 go k times
T(n)=T(n-k)+kc

when I stop some d 
n-k=0
n=k

T(n)=T(0)+nc
T(n)=d+nc

O(n)
'''
# Out:
# '\nT(0)=d  means some constant term\n\nT(n)=T(n-1)+c\n\n#step1:\n\nT(n)=T(n-2)+(n-1)+2c\n\n#step2:\nT(n)=T(n-3)+(n-2)+(n-1)+3c\n\nNow what I observe these n-3,n-2,n-1 go k times\nT(n)=T(n-k)+kc\n\nwhen I stop some d \nn-k=0\nn=k\n\nT(n)=T(0)+nc\nT(n)=d+nc\n\nO(n)\n'

# %%
#b. T(n) = 2T(n/2) + n
'''  
step1:
T(n)=2T(n/2)+n
T(n/2)=2T(n/4)+n/2
T(n)=2[2T(n/4)+n/2]+n
T(n)=4T(n/4)+2n     #1st equation

T(n)=2T(n/2)+n
T(n/4)=2T(n/8)+n/4
T(n)=4[2T(n/8)+n/4]+2n
T(n)=8T(n/8)+3n

T(n)=2^3(n/2^3)+3n
T(n)=2^kT(n/2^k)+kn

n/2^k=1

n=2^k

log2n=log2 2^k
k=log2n

T(n)=2^kT(n/2^k)+kn
T(n)=nT(1)+log2n.n

O(nlogn)
'''
# Out:
# '  \nstep1:\nT(n)=2T(n/2)+n\nT(n/2)=2T(n/4)+n/2\nT(n)=2[2T(n/4)+n/2]+n\nT(n)=4T(n/4)+2n     #1st equation\n\nT(n)=2T(n/2)+n\nT(n/4)=2T(n/8)+n/4\nT(n)=4[2T(n/8)+n/4]+2n\nT(n)=8T(n/8)+3n\n\nT(n)=2^3(n/2^3)+3n\nT(n)=2^kT(n/2^k)+kn\n\nn/2^k=1\n\nn=2^k\n\nlog2n=log2 2^k\nk=log2n\n\nT(n)=2^kT(n/2^k)+kn\nT(n)=nT(1)+log2n.n\n\nO(nlogn)\n'

# %%
#c. T(n) = 2T(n/2) + c

'''  
T(n)=2T(n/2)+c
T(n/2)=2T(n/4+)+c
T(n)=c[2T(n/4)+2c]+c
T(n)=4T(n/4)+3c  1st equation

T(n/4)=2T(n/8)+c
T(n)=4[2T(n/8)+c]+3c
T(n)=8T(n/8)+4c+3c
T(n)=8T(n/8)+7c

T(n)=2^k T(n/2^k)+(2^k-1)c

n/2^k=1

n=2^k
k=log2n

T(n)=2log2​nT(1)+(2log2​n−1)c
T(n)=nd+(n−1)c
T(n)=O(n)
'''
# Out:
# '  \nT(n)=2T(n/2)+c\nT(n/2)=2T(n/4+)+c\nT(n)=c[2T(n/4)+2c]+c\nT(n)=4T(n/4)+3c  1st equation\n\nT(n/4)=2T(n/8)+c\nT(n)=4[2T(n/8)+c]+3c\nT(n)=8T(n/8)+4c+3c\nT(n)=8T(n/8)+7c\n\nT(n)=2^k T(n/2^k)+(2^k-1)c\n\nn/2^k=1\n\nn=2^k\nk=log2n\n\nT(n)=2log2\u200bnT(1)+(2log2\u200bn−1)c\nT(n)=nd+(n−1)c\nT(n)=O(n)\n'

# %%
#d. T(n) = T(n/2) + c

''' 
T(n)=T(n/2)+c
T(n/2)=T(n/4)+c
T(n)=T(n/4)+2c

T(n/4)=T(n/8)+c
T(n)=T(n/8)+3c

T(n)=T(n/2^k)+kc

n/2^k=1

n=2^k
k=log2n

T(n)=T(1)+log2n+c

O(log2n)
'''
# Out:
# ' \nT(n)=T(n/2)+c\nT(n/2)=T(n/4)+c\nT(n)=T(n/4)+2c\n\nT(n/4)=T(n/8)+c\nT(n)=T(n/8)+3c\n\nT(n)=T(n/2^k)+kc\n\nn/2^k=1\n\nn=2^k\nk=log2n\n\nT(n)=T(1)+log2n+c\n\nO(log2n)\n'

# %%
#3. Given a recurrence relation, solve it using the recursive tree approach:

#a. T(n) = 2T(n-1) +1
'''
Level 0:
T(n)   →  +1 work

Level 1:
        T(n)
       /    \
   T(n−1)  T(n−1)


Level 2:
     T(n−2)  T(n−2)  T(n−2)  T(n−2)

n-k=0
n=k

1+2+4+8.....2^n

geomatrix series formula
2^n+1-1

O(2^n)
'''
# Out:
# '\nLevel 0:\nT(n)   →  +1 work\n\nLevel 1:\n        T(n)\n       /       T(n−1)  T(n−1)\n\n\nLevel 2:\n     T(n−2)  T(n−2)  T(n−2)  T(n−2)\n\nn-k=0\nn=k\n\n1+2+4+8.....2^n\n\ngeomatrix series formula\n2^n+1-1\n\nO(2^n)\n'

# %%
#b. T(n) = 2T(n/2) + n
'''
Level 0:
T(n)   →  work = n
Number of nodes = 1

Work at this node = n

Total work at Level 0 = n

Level 1:
          T(n)
         /    \
     T(n/2)  T(n/2)

Each T(n/2) does work = n/2

Number of nodes = 2

Total work at Level 1 = 2 * n/2=n

Level 2:
T(n/4)  T(n/4)  T(n/4)  T(n/4)

Number of nodes = 4

Work per node = n/4

Total work at Level 1 = 4 * n/4=n

n/2^k=1

n=2^k

k=log2n

O(nlogn)
'''
# Out:
# '\nLevel 0:\nT(n)   →  work = n\nNumber of nodes = 1\n\nWork at this node = n\n\nTotal work at Level 0 = n\n\nLevel 1:\n          T(n)\n         /         T(n/2)  T(n/2)\n\nEach T(n/2) does work = n/2\n\nNumber of nodes = 2\n\nTotal work at Level 1 = 2 * n/2=n\n\nLevel 2:\nT(n/4)  T(n/4)  T(n/4)  T(n/4)\n\nNumber of nodes = 4\n\nWork per node = n/4\n\nTotal work at Level 1 = 4 * n/4=n\n\nn/2^k=1\n\nn=2^k\n\nk=log2n\n\nO(nlogn)\n'
